# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsadaqathali/codingtask/blob/main/lc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
squares = [x ** 2 for x in range(1, 21) if x % 2 == 0]

print(squares)
# Out:
# [4, 16, 36, 64, 100, 144, 196, 256, 324, 400]
