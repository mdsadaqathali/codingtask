# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsadaqathali/codingtask/blob/main/dupremoval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
unique_values = list(set([1, 2, 2, 3, 4, 4, 5]))
print(unique_values)
# Out:
# [1, 2, 3, 4, 5]
