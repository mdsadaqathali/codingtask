# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsadaqathali/codingtask/blob/main/ideg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L1 = [1, 2, 3]
L2 = [1, 2, 3]

print(L1 == L2)
print(L1 is L2)
# Out:
# True
# False
