# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsadaqathali/codingtask/blob/main/dc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = {'a': 1, 'b': 2, 'c': 3, 'd': 4}

result = {key: value for key, value in data.items() if value > 2}

print(result)
# Out:
# {'c': 3, 'd': 4}
