# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsadaqathali/codingtask/blob/main/bitwiseswap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter a: "))
b = int(input("Enter b: "))

a = a ^ b
b = a ^ b
a = a ^ b

print("a =", a)
print("b =", b)
